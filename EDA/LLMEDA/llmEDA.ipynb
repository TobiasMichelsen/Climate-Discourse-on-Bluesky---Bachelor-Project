# %%
import pandas as pd

# %%
df = pd.read_pickle("LLM_classified_df.pkl")
df.head()
# Out:
#    cluster                                               text  \
# 0        6  siennaeverett.bsky.social on climate attitudes...
# 0        6  Appreciate juliefrancella.com simonmoyasmith.b...
# 0        6  Hello, Bluesky! We're thrilled to be here. Our...
# 0        6  After posters and lunch, President of dwdderwe...
# 0        6  Listen to Adam's podcasts acidhorizon.bsky.soc...
#
#                                             response
# 0  1. Climate - siennaeverett.bsky.social on clim...
# 0  1. Renewable Energy\n        2. Climate\n     ...
# 0  1. Renewable Energy\n        2. Fossil Fuels\n...
# 0  1. Climate\n        2. Climate services\n     ...
# 0  1. Renewable Energy\n        2. Fossil Fuels\n...

# %%
df6 = df[df.cluster == 6]
df6.shape
for i in range(df6.shape[0]):
    row = df.iloc[i]
    print("------------------\n")
    print(row.text)
    print("------------------\n")
    print(row.response)
    asd = row.text.split("\n")
# Out:
# ------------------
#
# siennaeverett.bsky.social on climate attitudes vchengm.bsky.social on bureaucracy nataliatrujillo.bsky.social on migration jydenham.bsky.social on Englishness fransplains.bsky.social on Tory pol. econ more great work from Bsky-less Bradley Ward, Mariana Borges, Michele Zadra, Deborah Timoni
# ------------------
#
# 1. Climate - siennaeverett.bsky.social on climate attitudes
#         2. Bureaucracy - vchengm.bsky.social on bureaucracy
#         3. Migration - nataliatru
# ------------------
#
# Appreciate juliefrancella.com simonmoyasmith.bsky.social appear johnfugelsang.bsky.social siriusxmprog.bsky.social discussing climatechange and energy exploration to support economy My SubStack addresses economic drivers creating this conundrum threatening Sustainable prosperity economy
# ------------------
#
# 1. Renewable Energy
#         2. Climate
#         3. Politics
#         4. Lifestyle
#         5. Science
#         6. Agriculture
#         7. Activism
# ...
