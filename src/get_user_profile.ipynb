# %%
pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting requests
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 1.6 MB/s eta 0:00:011
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.4.1-cp39-cp39-macosx_10_9_universal2.whl (197 kB)
#      |████████████████████████████████| 197 kB 2.4 MB/s eta 0:00:01
# Requirement already satisfied: idna<4,>=2.5 in /Users/tobiasmichelsen/Library/Python/3.9/lib/python/site-packages (from requests) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tobiasmichelsen/Library/Python/3.9/lib/python/site-packages (from requests) (2025.1.31)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 15.6 MB/s eta 0:00:01
# Installing collected packages: urllib3, charset-normalizer, requests
#   WARNING: The script normalizer is installed in '/Users/tobiasmichelsen/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed charset-normalizer-3.4.1 requests-2.32.3 urllib3-2.3.0
# WARNING: You are using pip version 21.2.4; however, version 25.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

def create_session(handle, password):
    """
    Logs in to Bluesky (bsky.social) with the given handle and password,
    and returns the 'accessJwt' from the createSession response.

    :param handle: Your Bluesky handle, e.g. "my-handle.bsky.social"
    :param password: Your Bluesky password
    :return: accessJwt (session token) as a string
    :raises: Exception if the login fails
    """

    # Replace this if you're using a different PDS (e.g., a custom server).
    endpoint = "https://bsky.social/xrpc/com.atproto.server.createSession"
    
    payload = {
        "identifier": handle,   # can be your handle, e.g. "my-handle.bsky.social"
        "password": password
    }

    # Make the POST request
    response = requests.post(endpoint, json=payload)

    # Check for a successful response
    if response.status_code == 200:
        data = response.json()
        # The field "accessJwt" is your session token
        return data["accessJwt"]
    else:
        # Raise an exception if something goes wrong (e.g., invalid credentials)
        raise Exception(f"Failed to create session: {response.status_code} {response.text}")
# Out:
# /Users/tobiasmichelsen/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
session_token = create_session("tobmic.bsky.social" , "qivyx7DDTyDkXba")

# %%
def get_user_profile(session_token, actor_handle):
    """
    Retrieves a user's profile given their handle (e.g., 'alice.bsky.social').
    Returns a JSON dict with profile info (DID, avatar, description, etc.).
    """
    endpoint = "https://bsky.social/xrpc/app.bsky.actor.getProfile"
    
    headers = {
        "Authorization": f"Bearer {session_token}"
    }
    
    params = {
        "actor": actor_handle
    }
    
    resp = requests.get(endpoint, headers=headers, params=params)
    if resp.status_code == 200:
        return resp.json()
    else:
        raise Exception(f"Failed to get profile: {resp.status_code} {resp.text}")

# %%
get_user_profile(session_token, actor_handle='tobmic.bsky.social')
# Out:
# {'did': 'did:plc:2xyl3n4a6iwyypv4ykwna2vi',
#  'handle': 'tobmic.bsky.social',
#  'displayName': '',
#  'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:2xyl3n4a6iwyypv4ykwna2vi/bafkreifiqsw6lon2ysterag3ktcvq6tc2yr242vsbfwrmtccqxo2khwypq@jpeg',
#  'associated': {'lists': 0,
#   'feedgens': 0,
#   'starterPacks': 0,
#   'labeler': False},
#  'viewer': {'muted': False, 'blockedBy': False},
#  'labels': [],
#  'createdAt': '2025-02-06T17:34:25.446Z',
#  'indexedAt': '2025-02-06T17:34:25.446Z',
#  'followersCount': 0,
#  'followsCount': 1,
#  'postsCount': 0}

# %%
def get_follows(session_token, actor_handle, limit=50, cursor=None):
    """
    Fetch the list of accounts that 'actor_handle' follows.
    Optional: specify 'limit' and 'cursor' for pagination.
    """
    endpoint = "https://bsky.social./xrpc/app.bsky.graph.getFollows"
    headers = {"Authorization": f"Bearer {session_token}"}
    
    params = {
        "actor": actor_handle,
        "limit": limit
    }
    if cursor:
        params["cursor"] = cursor
    
    resp = requests.get(endpoint, headers=headers, params=params)
    if resp.status_code == 200:
        return resp.json()  # includes 'cursor' for next page
    else:
        raise Exception(f"Failed to get follows: {resp.status_code} {resp.text}")


def get_followers(session_token, actor_handle, limit=50, cursor=None):
    """
    Fetch the list of accounts following 'actor_handle'.
    """
    endpoint = "https://bsky.social/xrpc/app.bsky.graph.getFollowers"
    headers = {"Authorization": f"Bearer {session_token}"}
    
    params = {
        "actor": actor_handle,
        "limit": limit
    }
    if cursor:
        params["cursor"] = cursor
    
    resp = requests.get(endpoint, headers=headers, params=params)
    if resp.status_code == 200:
        return resp.json()
    else:
        raise Exception(f"Failed to get followers: {resp.status_code} {resp.text}")

# %%
followers_data = get_followers(session_token, "biobab.bsky.social")
followers_data
# Out:
# {'followers': [],
#  'subject': {'did': 'did:plc:kfqvsnaktgllblu77a7gb3x7',
#   'handle': 'biobab.bsky.social',
#   'displayName': '',
#   'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:kfqvsnaktgllblu77a7gb3x7/bafkreicxok5ij2pswcqnjgzpkyftsvv3gxflrcyk2asysabtrvrrk7uw3u@jpeg',
#   'viewer': {'muted': False, 'blockedBy': False},
#   'labels': [],
#   'createdAt': '2025-01-30T13:20:31.445Z',
#   'indexedAt': '2025-01-30T13:20:31.445Z'}}

# %%
follows_data = get_follows(session_token, "biobab.bsky.social")
follows_data
# Out:
# {'follows': [{'did': 'did:plc:xlqcxpk53spbhlypj6wmvvke',
#    'handle': 'popbase.tv',
#    'displayName': 'Pop Base',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:xlqcxpk53spbhlypj6wmvvke/bafkreicieqzk3twxj6zeyd7gpm637zib277rkyciorvfu25whjhzn3542u@jpeg',
#    'associated': {'chat': {'allowIncoming': 'all'}},
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-09-03T22:04:10.910Z',
#    'description': 'Pop Base is your best source for all pop culture related entertainment, news, award show coverage, chart updates, statistics and more. | email@popbase.tv',
#    'indexedAt': '2025-02-07T09:28:50.044Z'},
#   {'did': 'did:plc:z72i7hdynmk6r22z27h6tvur',
#    'handle': 'bsky.app',
#    'displayName': 'Bluesky',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:z72i7hdynmk6r22z27h6tvur/bafkreihagr2cmvl2jt4mgx3sppwe2it3fwolkrbtjrhcnwjk4jdijhsoze@jpeg',
#    'associated': {'chat': {'allowIncoming': 'none'}},
#    'viewer': {'muted': False,
#     'blockedBy': False,
#     'following': 'at://did:plc:2xyl3n4a6iwyypv4ykwna2vi/app.bsky.graph.follow/3lhjmnlr2632j'},
#    'labels': [],
#    'createdAt': '2023-04-12T04:53:57.057Z',
#    'description': 'official Bluesky account (check username👆)\n\nBugs, feature requests, feedback: support@bsky.app',
#    'indexedAt': '2024-12-18T07:43:57.542Z'}],
#  'subject': {'did': 'did:plc:kfqvsnaktgllblu77a7gb3x7',
#   'handle': 'biobab.bsky.social',
#   'displayName': '',
#   'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:kfqvsnaktgllblu77a7gb3x7/bafkreicxok5ij2pswcqnjgzpkyftsvv3gxflrcyk2asysabtrvrrk7uw3u@jpeg',
#   'viewer': {'muted': False, 'blockedBy': False},
#   'labels': [],
#   'createdAt': '2025-01-30T13:20:31.445Z',
#   'indexedAt': '2025-01-30T13:20:31.445Z'}}

# %%
follows_data = get_follows(session_token, "sioldridge.bsky.social")
"Whats been done, fill the gap, innovative angle"
follows_data
rate limits
# Out:
# {'follows': [{'did': 'did:plc:m2ufb4ra3nh25vn32ybge6g3',
#    'handle': 'mariesnyder.bsky.social',
#    'displayName': 'Marie Snyder',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:m2ufb4ra3nh25vn32ybge6g3/bafkreicndqsx42crzpqynghwffwig3eh6p7dkodullcjrbuxsvdkuztmgy@jpeg',
#    'associated': {'chat': {'allowIncoming': 'following'}},
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2023-07-01T23:02:13.307Z',
#    'description': 'Mask and relax with an N95! I post and repost about covid, climate, conflicts, cycling, psychology, philosophy, and politics. Longreads at https://apuffofabsurdity.blogspot.com/ and https://3quarksdaily.com/3quarksdaily/author/mariesnyder',
#    'indexedAt': '2024-11-15T12:54:36.825Z'},
#   {'did': 'did:plc:fqb2kfuwlskwq635xopujwza',
#    'handle': 'jamesward81.bsky.social',
#    'displayName': 'James Ward',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:fqb2kfuwlskwq635xopujwza/bafkreic4u5dhpdm6iosdrj3r5joyyhejer7y4qdy6djawhifnrb6ln4fri@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-09-05T11:48:22.231Z',
#    'description': 'Campaigner at Adfree Cities // Host of the Better Without Billboards Podcast // Words in The Ecologist, Bristol Cable, Bristol 24/7 // Facilitator // Tall man. ',
#    'indexedAt': '2024-11-27T15:38:55.547Z'},
#   {'did': 'did:plc:5infkpvkk7wcmsyl7riqtz2d',
#    'handle': 'r3volution-project.bsky.social',
#    'displayName': 'R3VOLUTION Project',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:5infkpvkk7wcmsyl7riqtz2d/bafkreihqb4jn6vfaolduph3dd2uvfqike7zhps3fwloesp7iqkzl2v4dma@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2025-02-12T08:32:03.845Z',
#    'description': 'The EU-funded R3VOLUTION project aims to revolutionize industrial water management in Europe. Read more here: https://r3volution.eu/',
#    'indexedAt': '2025-02-13T08:04:47.042Z'},
#   {'did': 'did:plc:dupirzvlby7azzkrbke3qtmm',
#    'handle': 'annieleymarie.bsky.social',
#    'displayName': 'Annie Leymarie',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:dupirzvlby7azzkrbke3qtmm/bafkreidcgullvsr44c2qhqkyxyirhczi3xfrppcsogaw3ue6obaeklbxdy@jpeg',
#    'associated': {'chat': {'allowIncoming': 'following'}},
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2023-10-02T16:38:29.370Z',
#    'description': 'Nature / Climate / More-than-humans / Degrowth / Social justice / Food, Ag and Land Use / Energy / Retrofits / Transport \nLondon ',
#    'indexedAt': '2025-01-29T06:54:28.043Z'},
#   {'did': 'did:plc:lrecbvufsppwwur5xzveko4j',
#    'handle': 'stopburningtrees.bsky.social',
#    'displayName': 'Stop Burning Trees Coalition',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:lrecbvufsppwwur5xzveko4j/bafkreigqy27v6qqu6srhr23xr4zz7rld5te2i4oihfwa7c6dmfkmdyd55y@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2025-02-12T18:17:58.843Z',
#    'description': 'The Stop Burning Trees Coalition is a coalition of groups that collectively oppose the burning of trees in power stations like Drax. https://linktr.ee/sbtcoalition',
#    'indexedAt': '2025-02-12T18:19:01.744Z'},
#   {'did': 'did:plc:tfq75sn35s3z73qch7qdg524',
#    'handle': 'bolund.bsky.social',
#    'displayName': 'Per Bolund',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:tfq75sn35s3z73qch7qdg524/bafkreicgo5v4twogbndvnsguran5hdsheinjvs65lutbttzmqmeuwliwba@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [{'src': 'did:plc:tfq75sn35s3z73qch7qdg524',
#      'uri': 'at://did:plc:tfq75sn35s3z73qch7qdg524/app.bsky.actor.profile/self',
#      'cid': 'bafyreialhoboqto5zm5ufg5rftofvrmngkcrnu6iviqxshhdooke45k5va',
#      'val': '!no-unauthenticated',
#      'cts': '2024-11-15T14:01:43.956Z'}],
#    'createdAt': '2024-11-15T14:01:44.733Z',
#    'description': 'Researcher on Urban Nature-based Solutions @sthlmresilience Centre. \nPreviously party leader for the Green party, minister of environment, financial markets and deputy prime minister of Sweden.',
#    'indexedAt': '2025-01-28T10:57:42.745Z'},
#   {'did': 'did:plc:homcx7ojv3s4tcgetapb5etj',
#    'handle': 'floodmary.bsky.social',
#    'displayName': 'Mary Long-Dhonau OBE',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:homcx7ojv3s4tcgetapb5etj/bafkreid2xjt27lcwdmvycuptius54flmynfkas7hz3lzdnt5bfhm6xi3xy@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-08-18T12:45:22.887Z',
#    'description': "Passionate Property Flood Resilience (#PFR) advocate.\nI've been flooded & survived.\nPromoter of preparing for flooding. Recoverable repair & #BuildBackBetter. \n \nFloodMary.com",
#    'indexedAt': '2025-01-05T09:53:44.944Z'},
#   {'did': 'did:plc:czkm5h3lyqr5nvlrc6ek5zcn',
#    'handle': 'samljpage.bsky.social',
#    'displayName': 'Sam Page PhD',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:czkm5h3lyqr5nvlrc6ek5zcn/bafkreicjldq3x2753kgqbx3wt7qw6vdcetxwztxpgegimzejgz3t5ikhoe@jpeg',
#    'associated': {'chat': {'allowIncoming': 'following'}},
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-08-31T20:29:19.697Z',
#    'description': 'Green campaigner; New Scot #RejoinEU #BLM',
#    'indexedAt': '2024-11-16T11:36:13.972Z'},
#   {'did': 'did:plc:uwzvgmdqedeleh3aibirtrqp',
#    'handle': 'sustainableucl.bsky.social',
#    'displayName': 'Sustainable UCL ',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:uwzvgmdqedeleh3aibirtrqp/bafkreigljnm26xt4il6eajvvcc4higjnsor5gztlq62giixhokx5446dy4@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-12-17T14:41:28.443Z',
#    'description': "UCL's Sustainability hub, working with students and researchers to make #ChangePossible. Home of the UCL Climate Hub. Join us in making a sustainable UCL. ",
#    'indexedAt': '2024-12-17T15:17:45.743Z'},
#   {'did': 'did:plc:g36qdczaj3cybjsuwekmbvza',
#    'handle': 'uclgeography.bsky.social',
#    'displayName': 'UCL Department of Geography',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:g36qdczaj3cybjsuwekmbvza/bafkreihrjpcj6j3qjqphvn4pyz2llemjtpu6s56fe5i2tnsgxtmxu4ag6a@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-11-28T14:40:59.846Z',
#    'description': "UCL Department of Geography | One of the UK's largest and most prominent institutes for geographical study and research.\n\nucl.ac.uk/geography",
#    'indexedAt': '2024-11-28T15:39:56.145Z'},
#   {'did': 'did:plc:ymvhaurndnfbej3gh4o3go2g',
#    'handle': 'profmarkmaslin.bsky.social',
#    'displayName': 'Prof Mark Maslin',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:ymvhaurndnfbej3gh4o3go2g/bafkreicmi5lkuhlbhknqffh5pp3vvjdmfvny4utp6kapndbxmvv6viusdq@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [{'src': 'did:plc:ymvhaurndnfbej3gh4o3go2g',
#      'uri': 'at://did:plc:ymvhaurndnfbej3gh4o3go2g/app.bsky.actor.profile/self',
#      'cid': 'bafyreiajmp4ntwrvj2fn6tofkpj2zhvkintgkv4twbvcrwomhbqu745rf4',
#      'val': '!no-unauthenticated',
#      'cts': '2024-11-17T22:22:00.691Z'}],
#    'createdAt': '2024-11-17T22:22:01.378Z',
#    'description': '#ClimateChange Professor @ucl, author of #HumanPlanet, #CradleOfHumanity, #HowToSaveOurPlanet, member of Climate Crisis Advisory Group, Dad (He/Him)',
#    'indexedAt': '2024-12-14T16:33:21.643Z'},
#   {'did': 'did:plc:unoc3es5z6wheivheyo6wlqr',
#    'handle': 'libdemdaisy.bsky.social',
#    'displayName': 'Daisy Cooper MP 🔶',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:unoc3es5z6wheivheyo6wlqr/bafkreigkpiuh257ll5dbo32jaqviwcuamn6m3c3prvjywd4qty6xw2qj5m@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-11-14T10:23:57.983Z',
#    'description': 'Member of Parliament for St Albans.\n\n@libdems.org.uk Deputy Leader and Treasury Spokesperson.\n\n📧 Daisy.cooper.mp@parliament.uk',
#    'indexedAt': '2024-11-18T10:34:02.647Z'},
#   {'did': 'did:plc:7w7agckft746srx5kcu25mdh',
#    'handle': 'wolfgangcramer.net',
#    'displayName': 'Wolfgang Cramer',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:7w7agckft746srx5kcu25mdh/bafkreif27zofylw4ksoqicqtbx4xhgju36xq6vfkzgfbt25g7yzpcaafuq@jpeg',
#    'associated': {'chat': {'allowIncoming': 'following'}},
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2023-09-19T05:49:55.561Z',
#    'description': "#Climate & #biodiversity scientist, professor of global #ecology, #CNRS, MedECC, #IPCC, Acad. d'Agriculture de France, Chief Editor Regional Environmental Change.\n\nOccasional rail travel and bicycle geek. 🇩🇪 🇫🇷 🇬🇧 🇸🇪 🇳🇴 https://tinyurl.com/wcrame",
#    'indexedAt': '2025-02-11T09:29:51.545Z'},
#   {'did': 'did:plc:ina54vnh7f542nr7deyiedml',
#    'handle': 'stevedawe.bsky.social',
#    'displayName': 'Steve Dawe',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:ina54vnh7f542nr7deyiedml/bafkreieoikn4se2ol2dfohrojh2jeyyeqbah32c6ue3fczmga7rwng6wtm@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-10-11T17:37:02.109Z',
#    'description': 'Transport, Envt, Climate, life long Green Party and Buddhist. Writer at WEST ENGLAND BYLINES. Retd interdisciplinary social sci lecturer incl teaching Abt Climate/Envt/Devt Studies/Euro Studies. Married, parent, grandparent. Passionate Abt folk music.',
#    'indexedAt': '2024-10-11T18:02:48.709Z'},
#   {'did': 'did:plc:7furjdiwxlkmqqwp4tk6ed6g',
#    'handle': 'patrickdunleavy.bsky.social',
#    'displayName': 'Patrick Dunleavy',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:7furjdiwxlkmqqwp4tk6ed6g/bafkreicjnu656xv3ic7oknziqmhtu6q6vwaf5vp4unhpvbhkqm76trdtrq@jpeg',
#    'associated': {'chat': {'allowIncoming': 'following'}},
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-08-12T13:32:09.974Z',
#    'description': 'Emeritus Professor of Politics & Public Policy, London School of Economics & Political Science.\nInterests - digital era governance, democratic audit & renewal, theories of the state, elections & party competition. \nAnd in open social science, universities.',
#    'indexedAt': '2024-12-07T12:37:29.245Z'},
#   {'did': 'did:plc:xdyulf3o3z6i42wittimzjyq',
#    'handle': 'markpoynting.bsky.social',
#    'displayName': 'Mark Poynting',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:xdyulf3o3z6i42wittimzjyq/bafkreigthmyiioanbze3lz5uhttd3sglkrq4eslgw6tycgyqdx3qmoxexa@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2025-01-23T13:06:05.842Z',
#    'description': 'Climate and Environment Researcher at BBC News',
#    'indexedAt': '2025-01-23T13:08:20.543Z'},
#   {'did': 'did:plc:zeeblp562c3qakc2wprgrkwn',
#    'handle': 'gardenorganicuk.bsky.social',
#    'displayName': 'Garden Organic',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:zeeblp562c3qakc2wprgrkwn/bafkreicwggerhc7txagwmfmt56vnzxtphaldxzpmxxeanvme6qkul6u4vm@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-03-11T11:17:35.638Z',
#    'description': '🍃 Inspiring you & your community to grow #organically\n🔬 Advancing #organic growing research\n🌱 Home to the Heritage Seed Library\nhttps://linktr.ee/gardenorganic',
#    'indexedAt': '2025-02-04T09:25:41.545Z'},
#   {'did': 'did:plc:o7cvvivw7biqg6q6nhxarr5u',
#    'handle': 'jackwallington.com',
#    'displayName': 'Jack Wallington',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:o7cvvivw7biqg6q6nhxarr5u/bafkreihotvhpdyhlitqvo6gvp5l4ki5cnsto6aom6zfvwidp56fgm2qmta@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-02-07T13:23:09.896Z',
#    'description': 'Nature and garden writer | wildlife garden designer | landscape artist \nBooks: Wild about Weeds and A Greener Life \nNewsletter: WildWay.info\n(garden zone H4 / 8b-9a)',
#    'indexedAt': '2025-01-28T22:24:35.144Z'},
#   {'did': 'did:plc:n7kwa4v3xqpq6g3piiimdjxu',
#    'handle': 'markcnorwich.bsky.social',
#    'displayName': 'Mark C Norwich',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:n7kwa4v3xqpq6g3piiimdjxu/bafkreieg2mxk7qv3o35aqpsmf3ulny54hg7gz234kwdls7pjufpukdyl2u@jpeg',
#    'associated': {'chat': {'allowIncoming': 'all'}},
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2023-08-26T05:16:56.661Z',
#    'description': 'Environmental activist, Greenpeace speaker, dog dad, wild gardener, occasional cyclist',
#    'indexedAt': '2025-01-14T18:07:10.248Z'},
#   {'did': 'did:plc:o5cpx3efm42klbo72l6kss7s',
#    'handle': 'susannagrace.bsky.social',
#    'displayName': 'Susanna Grace 🦋',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:o5cpx3efm42klbo72l6kss7s/bafkreigepoa4lebrssm3cp6t5waakbr2omrm4dnhwv2xya6i66fcoajfjy@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-11-13T15:18:22.178Z',
#    'description': 'Politically progressive. Curious about everything from quantum physics to art history. Always up for great recipes and cute pets.\n#BlueCrew #FBR\n\U0001fad8',
#    'indexedAt': '2024-12-30T22:35:37.644Z'},
#   {'did': 'did:plc:xk4wkkyjm5egrtuglrtedf6k',
#    'handle': 'profsunstroke.bsky.social',
#    'displayName': 'Prof Sunstroke',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:xk4wkkyjm5egrtuglrtedf6k/bafkreiggsy6lojxzw6t6qc2hsowvjkyrrop5kepvzos5db2eyfkxtbyoay@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-11-15T06:00:44.635Z',
#    'description': 'Ten percent of the area of Oz can power the Planet with Solar!\nWe don’t need fossil fuels and we don’t need nuclear!\nSolar on every rooftop and batteries for everyone to soak up the excess.',
#    'indexedAt': '2024-12-16T23:01:52.743Z'},
#   {'did': 'did:plc:qkvahxetqlvs4odka224vmdb',
#    'handle': 'mary4future.bsky.social',
#    'displayName': '',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:qkvahxetqlvs4odka224vmdb/bafkreiehm575dqmh4eh7qnwycc56nlo2pycbcz2v2j6e2pmvnrwlhrevki@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-11-23T09:05:13.145Z',
#    'indexedAt': '2024-11-23T09:05:13.145Z'},
#   {'did': 'did:plc:axzjxagavzxckzwusy2p6ztv',
#    'handle': 'resurgencetrust.bsky.social',
#    'displayName': 'Resurgence',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:axzjxagavzxckzwusy2p6ztv/bafkreia366ppg47qwnd32wu6iqzdkb6wlswfle33fon3qlb7c7ytih6thy@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-11-20T13:09:49.769Z',
#    'description': 'Resurgence & Ecologist magazine has been at the forefront of the environmental and now regenerative movement for almost 60 years. Published by The Resurgence Trust, a small educational, UK charity: www.resurgence.org - championing and celebrating Nature.',
#    'indexedAt': '2024-11-25T15:21:10.245Z'},
#   {'did': 'did:plc:uyjz2ncnxleabkut565hzzfp',
#    'handle': 'sashaetkind.bsky.social',
#    'displayName': 'Alexander Etkind',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:uyjz2ncnxleabkut565hzzfp/bafkreigpiqivgdtitoefjjvibmsg47yedlvq4ftqadh55aa3geskwu54ta@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2023-09-28T15:44:21.917Z',
#    'description': 'Professor of CEU in Vienna. A historian who teaches IR and the Anthropocene, but mostly thinks and comments about the current war.  I ban, with or without warning',
#    'indexedAt': '2024-12-01T23:07:24.746Z'},
#   {'did': 'did:plc:rkptrf5fxri46gownhaqipa2',
#    'handle': 'simonjackbbc.bsky.social',
#    'displayName': 'Simon Jack',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:rkptrf5fxri46gownhaqipa2/bafkreiclrnhnqrmrwis7hdumm4xuiumuv4lhiazpqyzpbilv5hp4rjbiwi@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-11-20T19:31:54.308Z',
#    'description': 'BBC Business Editor\nToday Programme\nGood Bad Billionaire',
#    'indexedAt': '2024-11-26T07:05:14.046Z'},
#   {'did': 'did:plc:7i6qyjt427sjvjwpngi73id7',
#    'handle': 'martinjhodson.bsky.social',
#    'displayName': 'Martin Hodson',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:7i6qyjt427sjvjwpngi73id7/bafkreigcgmdfaoteoo7wg6kgerdncg6vca623qx5kk3jxxkxenqinqsr54@jpeg',
#    'associated': {'chat': {'allowIncoming': 'following'}},
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-01-14T16:58:25.416Z',
#    'description': 'Work at both universities in Oxford, UK. Teach climate and biodiversity loss. Research in plant, archaeological and environmental science. Investigating carbon sequestration in phytoliths within the soil. Principal Tutor for www.cres.org.uk',
#    'indexedAt': '2024-11-17T04:59:46.930Z'},
#   {'did': 'did:plc:4tbobykukxwhyhqk3ocgpga6',
#    'handle': 'adybee.bsky.social',
#    'displayName': ' AdyBee 🐝',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:4tbobykukxwhyhqk3ocgpga6/bafkreibz3nyvmqjedfl3mzvtzymxndrwmqnyz3qadncqxatliud5q6izta@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-11-14T07:02:24.879Z',
#    'description': 'Memes do a better job than mainstream media (bar set low🤨). Chaos is the plan #Confuse #CreateDoubt #BuryTheEvidence. Miffed about… #ToryCovidCatastrophe #LongCovid #WealthInequality and HOW they get away with it 🤬. #MemeForToday ❤️ #Horses   #Cleethorpes 🇬🇧',
#    'indexedAt': '2024-12-02T06:21:32.445Z'},
#   {'did': 'did:plc:uukph2nd42aisskw4rgzopw3',
#    'handle': 'lizcrosbie.bsky.social',
#    'displayName': 'Liz Crosbie #AllianceNowUK #RebootGB #FBPE',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:uukph2nd42aisskw4rgzopw3/bafkreie2m7zqtceafo56foy62mj4g2whq3h5kqyotlh3c7e63chuoziv2e@jpeg',
#    'associated': {'chat': {'allowIncoming': 'following'}},
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2023-07-22T11:10:45.399Z',
#    'description': 'Interested in politics & environmental issues. Ex UK Green Party, then 30+ years as a sustainability professional. Back into UK politics in Reboot GB. Now leading AllianceNow UK, working together for a new democracy. Plus gardening, travel & art. ',
#    'indexedAt': '2024-09-17T08:50:54.605Z'},
#   {'did': 'did:plc:l6kcvkc4x3lxidqtkrvtataq',
#    'handle': 'enviroprof.bsky.social',
#    'displayName': 'Dr. Kenneth A. Gould',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:l6kcvkc4x3lxidqtkrvtataq/bafkreida2mtp7t5gizrhmt7izvxnvv7muyrcd2njvnqid6wsr5rzn7xqii@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2023-11-06T13:21:15.691Z',
#    'description': 'Environmental sociologist. Climate change. Environmental justice. Sustainable development. Treadmill of Production. Green gentrification.',
#    'indexedAt': '2025-02-11T04:23:02.444Z'},
#   {'did': 'did:plc:jqc2ru54ywtkrpdftcfnjxbh',
#    'handle': 'watershed-i.bsky.social',
#    'displayName': 'WATERSHED Investigations',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:jqc2ru54ywtkrpdftcfnjxbh/bafkreiduoqzn5qmx3qdrt4fzws5ta5cuofbcv6nz546g4j2ycm5alqlbam@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-11-22T09:45:52.854Z',
#    'description': 'Award-winning independent not-for-profit investigative journalism in the public interest. \n\nhttps://watershedinvestigations.com/\n\nWatershed is: \n@rachelsalvidge.bsky.social\n@leanahosea.bsky.social\nPosts by Chloe',
#    'indexedAt': '2025-01-20T19:33:31.144Z'},
#   {'did': 'did:plc:zt46rgi7jhgmn7oggsco7wvj',
#    'handle': 'andersaslund.bsky.social',
#    'displayName': 'Anders Åslund',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:zt46rgi7jhgmn7oggsco7wvj/bafkreiei6gim75eoa3p445vbhnbssdasoeolcbxmh4lyb7hhcxipeydz3m@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-11-11T20:24:53.703Z',
#    'description': 'Economist & author, specializing in the economics of Eastern Europe, especially Russia & Ukraine.',
#    'indexedAt': '2024-11-17T21:16:12.555Z'},
#   {'did': 'did:plc:aw426jbgw7drhivb4ijrizlu',
#    'handle': 'leftistlawyer.com',
#    'displayName': 'Sheryl Weikal (The Leftist Lawyer)',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:aw426jbgw7drhivb4ijrizlu/bafkreihbxm2azbokijs2qdlwuvt3vxbpjztqqvt5ln2tqyd3s4kgbqppwq@jpeg',
#    'associated': {'chat': {'allowIncoming': 'none'}},
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [{'src': 'did:plc:aw426jbgw7drhivb4ijrizlu',
#      'uri': 'at://did:plc:aw426jbgw7drhivb4ijrizlu/app.bsky.actor.profile/self',
#      'cid': 'bafyreie626ry7kkfteaqc5mrdipnwvdzd6hvip2iauo2urp7ml57hbecmu',
#      'val': '!no-unauthenticated',
#      'cts': '2024-11-11T20:13:36.511Z'}],
#    'createdAt': '2024-11-11T20:13:37.609Z',
#    'description': "@mistymotors.net's wife. Proudly trans pay-whatever-you-can attorney in IL. No legal advice here, not your lawyer. She/her. If you like my work, buy me a coffee! https://ko-fi.com/theleftistlawyer",
#    'indexedAt': '2025-01-31T16:51:26.446Z'},
#   {'did': 'did:plc:rp3fspydnlivnhkcqjyemf2j',
#    'handle': 'keelingcurve.bsky.social',
#    'displayName': 'The Keeling Curve',
#    'associated': {'chat': {'allowIncoming': 'following'}},
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-04-04T16:24:50.542Z',
#    'description': "Official daily update on atmospheric CO2 levels in the post-400 ppm era from Scripps Institution of Oceanography's iconic Keeling Curve.",
#    'indexedAt': '2024-12-21T17:13:58.144Z'},
#   {'did': 'did:plc:yjdrh5miui3s423adnpnj3ml',
#    'handle': 'angelaisfranc.bsky.social',
#    'displayName': 'Angela Francis',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:yjdrh5miui3s423adnpnj3ml/bafkreicffmb2muoeeomlesy3vqtpcfildpaga7zfkampvvb6czej64x6oi@jpeg',
#    'associated': {'chat': {'allowIncoming': 'following'}},
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-08-16T19:21:01.886Z',
#    'description': 'Director of Policy Solutions WWF UK, into economics, trade, innovation and environment policy, opinions my own.\n\nBit of my heart always in Germany, Derbyshire, Scotland, Canada, East of England, Trinidad, Jamaica and on a rugby pitch. Now in London.',
#    'indexedAt': '2024-11-16T23:51:13.932Z'},
#   {'did': 'did:plc:mul6fsf64prbtvxlrglptioz',
#    'handle': 'stephaniekelton.bsky.social',
#    'displayName': 'Stephanie Kelton',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:mul6fsf64prbtvxlrglptioz/bafkreig7azc3xj7pepoliqaxa7w7lnc6zwcrgqpnbneh2z2afje5frkdxe@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2023-07-12T19:01:56.986Z',
#    'description': 'Author of the NYT bestseller The Deficit Myth. Professor of Economics and Public Policy at Stony Brook University. Writer of newsletter https://stephaniekelton.substack.com/',
#    'indexedAt': '2024-11-26T11:50:09.447Z'},
#   {'did': 'did:plc:hnunsxs4l3nsge2d4fuil7w4',
#    'handle': 'drwillb.bsky.social',
#    'displayName': 'Will Bradshaw',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:hnunsxs4l3nsge2d4fuil7w4/bafkreid2xmtqodkrszrol3lumc4tyfu27voxjyv3zihieb7kk5an6eglgq@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2025-01-02T16:44:29.643Z',
#    'description': "Science and politics and stuff. Structural biologist @cmd.ox.ac.uk. Working on Alzheimer's. Views own.",
#    'indexedAt': '2025-02-03T17:48:37.943Z'},
#   {'did': 'did:plc:t6u36m5kitdaq6igymuse4b4',
#    'handle': 'profpaul.bsky.social',
#    'displayName': 'Prof Paul Williams',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:t6u36m5kitdaq6igymuse4b4/bafkreiczkvflbi6mmqeqyxovw7tpr6zaigcomfhvjg7znpmkozqcuutdwu@jpeg',
#    'associated': {'chat': {'allowIncoming': 'all'}},
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-11-13T20:35:57.773Z',
#    'description': 'Professor of Atmospheric Science at University of Reading. Studies turbulence, jet streams, aviation, climate change.\n\nhttps://www.met.reading.ac.uk/~williams/',
#    'indexedAt': '2024-12-18T21:15:36.743Z'},
#   {'did': 'did:plc:hdcgjs6ukypilaz4mo2bgfxs',
#    'handle': 'leighsus.bsky.social',
#    'displayName': 'Leigh Jones',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:hdcgjs6ukypilaz4mo2bgfxs/bafkreidf656ysp65mujsbugmnyplx5m3fwxh4h7bkkr7sm6x7na7ksaocq@jpeg',
#    'associated': {'chat': {'allowIncoming': 'all'}},
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2023-08-19T10:49:57.278Z',
#    'description': 'Freelance journalist. Investigations, news, writing, BBC Radio Tees, BBC Radio Newcastle etc. \n\nEditor, The Teesside Lead. \n\n🔗 https://theteessidelead.substack.com\n\nUsed to work in music. Ex-Yorkshire Post Teesworks expert. Oh, and once I saw a blimp.',
#    'indexedAt': '2025-01-02T16:22:00.144Z'},
#   {'did': 'did:plc:6fcevbohk6ayqnztnvint3zr',
#    'handle': 'researcherog.bsky.social',
#    'displayName': 'Mike Robinson - The Researcher OG - #CannabisMyMedicine',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:6fcevbohk6ayqnztnvint3zr/bafkreiexxkx7srjeoyeib4qfzh2jfjaqyo3swybbiopof6wklvjn3a756a@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2025-01-26T14:50:03.044Z',
#    'description': 'Founder Global Cannabinoid Research Center 2018, ECS education (Endocannabinoid System) is key. In past 2 decades I kicked Cancer to the Curb 4x - Fighting for 5x now. Beat a 24yr Opioid addiction ~ I Love Weed ~ Independent, Former Civil Rights Lobbyist 💙',
#    'indexedAt': '2025-02-13T02:21:17.645Z'},
#   {'did': 'did:plc:bboh7hfktugbin4jzd2nfwnr',
#    'handle': 'louromain.bsky.social',
#    'displayName': 'Louise Romain',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:bboh7hfktugbin4jzd2nfwnr/bafkreigzwijmddmtak6ygp3gppapaose4vsni3u7sriv46ycxfqoj5twae@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2025-01-07T11:18:00.643Z',
#    'description': "Anthropologist, Campaigner for multispecies justice and Indigenous, Sound artist and Podcast producer of 'Circle of Voices'. I also work with The Spaceship Earth Podcast and Moral Imaginations.\n📍 Earthling based in Stroud, UK.",
#    'indexedAt': '2025-01-07T11:25:35.144Z'},
#   {'did': 'did:plc:prsl5ccbxtptji35njeoeld4',
#    'handle': 'helenkopnina.bsky.social',
#    'displayName': 'Dr. Helen Kopnina ',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:prsl5ccbxtptji35njeoeld4/bafkreifjkvcgqwkik2wzu7drwatdqblnrvht67e7wzwbmw6igbku7hsyja@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-11-23T08:50:05.246Z',
#    'description': '#Sustainability scholar @northumbriauni.bsky.social #EnvironmentalEducation #SustainableBusiness #Biodiversity #Animals #Climate Wary of polarization, viral slogans & echo chambers https://scholar.google.nl/citations?user=pE0rWdgAAAAJ&hl=nl',
#    'indexedAt': '2025-02-12T12:54:30.845Z'},
#   {'did': 'did:plc:jpsk4fechhyuy76m6qigbjlu',
#    'handle': 'galba.uk',
#    'displayName': 'GALBA - Group for Action on Leeds Bradford Airport',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:jpsk4fechhyuy76m6qigbjlu/bafkreihc5lij6ppso7b2ph7u5jrnss4gre4j2rmc3od62avxrxhcvrdlsu@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-11-05T16:15:20.280Z',
#    'description': 'Say NO to Leeds Bradford Airport expansion.\nSay YES to a safer, greener and quieter future.\n🌎 http://linktr.ee/galba',
#    'indexedAt': '2025-02-07T17:10:12.244Z'},
#   {'did': 'did:plc:m526tw7vojc336y7onxzmnpv',
#    'handle': 'danmiller999.bsky.social',
#    'displayName': 'Dan Miller',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:m526tw7vojc336y7onxzmnpv/bafkreie65vmm45sxmy44yacdxsb4ubmsra4px6opff6ziw4ythynsyw4xe@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-09-09T15:38:32.527Z',
#    'description': 'ClimateTech VC. Postings on climate change, CDR, SRM, climate policy & pinball. Host of Climate Chat on YouTube: https://www.youtube.com/@climatechat/streams',
#    'indexedAt': '2024-12-07T18:50:37.445Z'},
#   {'did': 'did:plc:r2f5drbpj5krdn6ysxpifipb',
#    'handle': 'rebelhack.bsky.social',
#    'displayName': 'Steve Tooze',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:r2f5drbpj5krdn6ysxpifipb/bafkreihrhtdketcmzlrgsqjngkiea23r7inwbjmafg3fuledrpo46avawq@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-08-13T21:08:04.974Z',
#    'description': "Recovering former Murdoch tabloid hack working off the bad karma by campaigning for an oligarch-free media, and creating stories around nonviolent direct action for the climate with Extinction Rebellion and Insure Our Survival. I'm a freelance writer too.",
#    'indexedAt': '2025-01-15T17:36:49.443Z'},
#   {'did': 'did:plc:6352mbfa3tixl4u4enjzyk4g',
#    'handle': 'michellec66.bsky.social',
#    'displayName': 'Michelle Charlesworth',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:6352mbfa3tixl4u4enjzyk4g/bafkreidf45cxdo37ccph2dea6bq6kx6laene6tlnhaj7itthop7dfakuki@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-11-14T07:20:13.276Z',
#    'description': 'Barred from Twitter 🤷\u200d♀️🦺🧯🇵🇸Activist. Grandma, Co founder of oneplanetabingdon.org. Many arrests for non violent direct action. Prison for holding a placard Just Stop Oil🦺. Prison for glueing myself to the dock in protest of the system. Love over hate.♥️',
#    'indexedAt': '2025-01-31T09:36:30.545Z'},
#   {'did': 'did:plc:l4o7ub4fr34lteggp4jp6ukl',
#    'handle': 'andreassieber.bsky.social',
#    'displayName': 'Andreas Sieber',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:l4o7ub4fr34lteggp4jp6ukl/bafkreicjywji7bydtsrv7krpg5wmrcphh3qpt6d6cb55ht3krixhi7jope@jpeg',
#    'associated': {'chat': {'allowIncoming': 'following'}},
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2023-12-23T10:40:06.246Z',
#    'description': 'Associate Director of Policy & Campaigns @350.org\nCo-board chair TogetherForFuture\n\nClimate, Energy, Geopolitics\nViews = my own',
#    'indexedAt': '2025-02-07T13:10:46.344Z'},
#   {'did': 'did:plc:be2sjl64dw3atp3liuqgtaek',
#    'handle': 'rob-marchant.bsky.social',
#    'displayName': 'Rob Marchant',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:be2sjl64dw3atp3liuqgtaek/bafkreiar6jhlrbojl7r55in35cxoladortkfvgxn5pjuszh6qonuvdcfde@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-11-27T14:13:20.144Z',
#    'description': 'Prof Rob Marchant is passionate about Mountain ecosystems, cultures and livelihoods, particularly across the Global South where he works with Universities, NGOs and international organisations.',
#    'indexedAt': '2025-01-31T06:27:09.644Z'},
#   {'did': 'did:plc:xl3go5xn25bceg3jn5dgh7yr',
#    'handle': 'climatecatalyst.bsky.social',
#    'displayName': 'Climate Catalyst',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:xl3go5xn25bceg3jn5dgh7yr/bafkreidlkkab4lrugx4fmhs5p5cjscmxcoecklj6nyqaog5cehazndijfa@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-11-11T18:11:14.782Z',
#    'description': 'Climate Catalyst sparks collective action on pivotal climate challenges to build power and drive urgent government action towards a 1.5C future. \nVisit www.climatecatalyst.org to learn more about our work.',
#    'indexedAt': '2024-12-02T13:43:04.645Z'},
#   {'did': 'did:plc:zv2nwkgn3qebc4iz6tnlo6rj',
#    'handle': 'oxfameu.bsky.social',
#    'displayName': 'Oxfam EU',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:zv2nwkgn3qebc4iz6tnlo6rj/bafkreicymgshc6x5lms2xylkmdi4we7awhp5vmp5rar3q656o45wnbeit4@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-12-04T14:48:43.346Z',
#    'description': 'Advocating for EU policies that fight inequality - now and for the long term.\n\nJournalist queries? 📩 eumedia@oxfam.org\n\nhttps://www.oxfam.org/en/eu ',
#    'indexedAt': '2024-12-04T15:52:57.846Z'},
#   {'did': 'did:plc:3gjfuj376aawp3typahyd55l',
#    'handle': 'clienteartheur.bsky.social',
#    'displayName': 'ClientEarth Europe',
#    'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:3gjfuj376aawp3typahyd55l/bafkreig2wvzgnlz4lxa5nrfetnpcmw2ooo2o7iurewca5schcz66bbdopy@jpeg',
#    'viewer': {'muted': False, 'blockedBy': False},
#    'labels': [],
#    'createdAt': '2024-12-05T11:02:07.146Z',
#    'description': '⚖️News and comments on our legal and advocacy work from across Europe. Part of @ClientEarth’s global work to use the power of the law to protect life on Earth.',
#    'indexedAt': '2024-12-05T16:52:03.940Z'}],
#  'subject': {'did': 'did:plc:cz67fdgcmuhkhei3upfb4ces',
#   'handle': 'sioldridge.bsky.social',
#   'displayName': 'Simon Oldridge #CANBill',
#   'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:cz67fdgcmuhkhei3upfb4ces/bafkreiczldmxxaxr6kkizqdz3la4kao2btcki2l5dt6abgy3ftbgmj7hye@jpeg',
#   'viewer': {'muted': False, 'blockedBy': False},
#   'labels': [],
#   'createdAt': '2023-10-30T09:40:40.177Z',
#   'description': 'UK climate & nature policy | \nAdviser at ZeroHour.uk - #CANBill | Research at https://www.mpwatch.org | Cofounder https://www.southdevonprimary.org | former manufacturing CEO & business consultant | Moog 🎹',
#   'indexedAt': '2025-01-16T16:27:25.343Z'},
#  'cursor': '3lgqrojltvz2e'}
